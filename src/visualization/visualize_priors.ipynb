# %%
from src.visualization import visualize_prior
from src.common import G2OpGymEnv
from src.common import BusConnectivityGraphObsSpace
from src.nri import prior_from_env


env = G2OpGymEnv(obs_space_creation=lambda e: BusConnectivityGraphObsSpace(e.observation_space))
_ = visualize_prior(prior_from_env(1.0, env))
_ = visualize_prior(prior_from_env(0.5, env))
_ = visualize_prior(prior_from_env(0.0, env))
